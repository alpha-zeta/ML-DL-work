# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as lr
from sklearn.linear_model import LogisticRegression as logi
from sklearn.model_selection import train_test_split as tts
import seaborn as sns
from sklearn.ensemble import ExtraTreesClassifier as Ext
from sklearn.preprocessing import LabelEncoder
import joblib as jb
from sklearn import datasets
from sklearn import preprocessing as ppr

# %%
 
iris=datasets.load_iris()
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                  5.1               3.5  ...               0.2     0.0
# 1                  4.9               3.0  ...               0.2     0.0
# 2                  4.7               3.2  ...               0.2     0.0
# 3                  4.6               3.1  ...               0.2     0.0
# 4                  5.0               3.6  ...               0.2     0.0
# ..                 ...               ...  ...               ...     ...
# 145                6.7               3.0  ...               2.3     2.0
# 146                6.3               2.5  ...               1.9     2.0
# 147                6.5               3.0  ...               2.0     2.0
# 148                6.2               3.4  ...               2.3     2.0
# 149                5.9               3.0  ...               1.8     2.0
#
# [150 rows x 5 columns]

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
dfn=df.copy()
eval=dfn.groupby('target').mean()
eval
# Out:
#         sepal length (cm)  ...  petal width (cm)
# target                     ...
# 0.0                 5.006  ...             0.246
# 1.0                 5.936  ...             1.326
# 2.0                 6.588  ...             2.026
#
# [3 rows x 4 columns]

# %% [markdown]
# FEATURE TARGET DISSECTION

# %%
Y=df.target
X=df.drop(['target'],axis=1)

# %% [markdown]
# TRAINING AND TEST AND EVALUATION

# %%
for i in range(1,10):
  Xtr,Xte,ytr,yte=tts(X,Y,test_size=i/10)
  Xtrn=ppr.scale(Xtr)
  Xten=ppr.scale(Xte)
  model=logi()
  model.fit(Xtrn,ytr)
  print(model.score(Xten,yte))
# Out:
# 0.9333333333333333
# 0.9666666666666667
# 1.0
# 0.9833333333333333
# 0.84
# 0.9666666666666667
# 0.8380952380952381
# 0.8916666666666667
# 0.7851851851851852

# %%
Xtr,Xte,ytr,yte=tts(X,Y,test_size=0.1)
Xtrn=ppr.scale(Xtr)
Xten=ppr.scale(Xte)
model=logi()
model.fit(Xtrn,ytr)
print(model.score(Xten,yte))
# Out:
# 0.9333333333333333

# %% [markdown]
# DUMPING MODEL

# %%
jb.dump(model,'iris_model')
# Out:
# ['iris_model']
